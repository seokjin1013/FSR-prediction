# %%
import ray.tune
import ray.air
import ray.air.integrations.wandb
import ray.tune.schedulers
import torch
import numpy as np
import pandas as pd
import sklearn.preprocessing
import sklearn.metrics
import os

# %%
class LSTM(torch.nn.Module):
    def __init__(self, input_size, hidden_size, num_layer, output_size):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layer = num_layer
        self.output_size = output_size
        self.encoder = torch.nn.LSTM(input_size, hidden_size, num_layer)
        self.decoder = torch.nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        x, _ = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, X_df, y_df, index):
        assert(len(X_df) == len(y_df))
        self.X_df = X_df
        self.y_df = y_df
        self.index = index

    def __len__(self):
        return len(self.index)
    
    def __getitem__(self, idx):
        import numpy as np
        X = self.X_df.loc[self.index[idx]].to_numpy().astype(np.float32)
        y = self.y_df.loc[self.index[idx]].to_numpy().astype(np.float32)
        return X, y

# %%
class Trainable(ray.tune.Trainable):
    def setup(self, config):
        model = config['model']
        model_args = config['model_args']
        criterion = config['criterion']
        optimizer = config['optimizer']
        lr = config['lr']

        self.model = model(**model_args)
        self.criterion = criterion()
        self.optimizer = optimizer(self.model.parameters(), lr=lr)

        data = pd.DataFrame(np.random.normal(size=(10000, 4)), columns=['A', 'B', 'C', 'D'])
        train_index = [pd.Index(np.arange(500 * (i), 500 * (i + 1))) for i in range(10)]
        test_index = [pd.Index(np.arange(500 * (10 + i), 500 * (10 + i + 1))) for i in range(10)]
        scaler = sklearn.preprocessing.StandardScaler()
        data[:] = scaler.fit_transform(data)
        train_dataset = Dataset(data[['A', 'B']], data[['C', 'D']], train_index)
        test_dataset = Dataset(data[['A', 'B']], data[['C', 'D']], test_index)
        
        self.train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=None)
        self.test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=None)
    
    def step(self):
        self.model.train()
        for X, y in self.train_loader:
            pred = self.model(X)
            loss = self.criterion(pred, y)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
        self.model.eval()
        with torch.no_grad():
            mae, mse, mape, num = [], [], [], []
            for X, y in self.test_loader:
                pred = self.model(X)
                mae.append(sklearn.metrics.mean_absolute_error(y, pred.cpu().detach()))
                mse.append(sklearn.metrics.mean_squared_error(y, pred.cpu().detach()))
                mape.append(sklearn.metrics.mean_absolute_percentage_error(y, pred.cpu().detach()))
                num.append(len(y))
            mae = np.average(mae, weights=num)
            mse = np.average(mse, weights=num)
            mape = np.average(mape, weights=num)
            rmse = mse ** 0.5
        return {'rmse': rmse, 'mae':mae, 'mape':mape}

    def save_checkpoint(self, tmp_checkpoint_dir):
        checkpoint_path = os.path.join(tmp_checkpoint_dir, "model.pth")
        torch.save(self.model.state_dict(), checkpoint_path)
        return tmp_checkpoint_dir
    
    def load_checkpoint(self, tmp_checkpoint_dir):
        checkpoint_path = os.path.join(tmp_checkpoint_dir, "model.pth")
        self.model.load_state_dict(torch.load(checkpoint_path))

# %%
tuner = ray.tune.Tuner(
    trainable=Trainable,
    tune_config=ray.tune.TuneConfig(
        metric='rmse',
        mode='min',
        num_samples=-1, 
        scheduler=ray.tune.schedulers.ASHAScheduler(
            max_t=1,
            grace_period=1,
            reduction_factor=2,
            brackets=1,
        ),
    ),
    param_space={
        'lr':ray.tune.loguniform(1e-5, 1e-2),
        'model':LSTM,
        'model_args':{
            'input_size':2, 
            'hidden_size':ray.tune.choice([8, 16, 32, 64, 128, 256, 512]), 
            'num_layer':ray.tune.randint(1, 8), 
            'output_size':2,
        },
        'criterion': torch.nn.MSELoss, 
        'optimizer': torch.optim.Adam,
    },
    run_config=ray.air.RunConfig(
        checkpoint_config=ray.air.CheckpointConfig(
            num_to_keep=3,
            checkpoint_score_attribute='rmse',
            checkpoint_score_order='min',
            checkpoint_frequency=5,
            checkpoint_at_end=True,
        ), 
    ),
)
results = tuner.fit()
# Out:
# 2023-07-01 11:07:42,472	INFO worker.py:1627 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# 2023-07-01 11:07:43,798	INFO tune.py:226 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-07-01 11:56:37</td></tr>
# <tr><td>Running for: </td><td>00:48:53.21        </td></tr>
# <tr><td>Memory:      </td><td>5.7/7.7 GiB        </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=735<br>Bracket: Iter 1.000: -1.0026798460830604<br>Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#   ... 734 more trials not shown (7 PENDING, 726 TERMINATED)
#
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc                 </th><th style="text-align: right;">         lr</th><th style="text-align: right;">    model_args/hidden_si
# ze</th><th style="text-align: right;">  model_args/num_layer</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">     mae</th><th style="text-align: right;">   mape</th></tr>
# </thead>
# <tbody>
# <tr><td>Trainable_10c93_00730</td><td>RUNNING   </td><td>172.26.215.93:260314</td><td style="text-align: right;">0.000546645</td><td style="text-align: right;">512</td><td style="text-align: right;">                     5</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00732</td><td>RUNNING   </td><td>172.26.215.93:260431</td><td style="text-align: right;">1.91411e-05</td><td style="text-align: right;">512</td><td style="text-align: right;">                     4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00735</td><td>RUNNING   </td><td>172.26.215.93:260725</td><td style="text-align: right;">1.09245e-05</td><td style="text-align: right;">512</td><td style="text-align: right;">                     2</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00738</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">0.000670349</td><td style="text-align: right;">  8</td><td style="text-align: right;">                     6</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00739</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">0.00128202 </td><td style="text-align: right;">128</td><td style="text-align: right;">                     7</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00740</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">1.42186e-05</td><td style="text-align: right;"> 16</td><td style="text-align: right;">                     3</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00741</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">3.62498e-05</td><td style="text-align: right;"> 32</td><td style="text-align: right;">                     6</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00742</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">1.10074e-05</td><td style="text-align: right;"> 64</td><td style="text-align: right;">                     5</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00743</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">7.55481e-05</td><td style="text-align: right;">128</td><td style="text-align: right;">                     4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00744</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">0.000462501</td><td style="text-align: right;"> 32</td><td style="text-align: right;">                     6</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00745</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">0.00532287 </td><td style="text-align: right;"> 32</td><td style="text-align: right;">                     4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00746</td><td>PENDING   </td><td>                    </td><td style="text-align: right;">0.000110196</td><td style="text-align: right;"> 16</td><td style="text-align: right;">                     1</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">        </td><td style="text-align: right;">       </td></tr>
# <tr><td>Trainable_10c93_00000</td><td>TERMINATED</td><td>172.26.215.93:205480</td><td style="text-align: right;">0.000730363</td><td style="text-align: right;">128</td><td style="text-align: right;">                     2</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.35742 </td><td style="text-align: right;">0.998567</td><td style="text-align: right;">0.796665</td><td style="text-align: right;">1.09199</td></tr>
# <tr><td>Trainable_10c93_00001</td><td>TERMINATED</td><td>172.26.215.93:205481</td><td style="text-align: right;">2.39947e-05</td><td style="text-align: right;">256</td><td style="text-align: right;">                     7</td><td style="text-align: right;">     1</td><td style="text-align: right;">       13.4919  </td>
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name           </th><th>date               </th><th>done  </th><th>hostname       </th><th style="text-align: right;">  iterations_since_restore</th><th style="text-align: right;">     mae</th><th style="text-align: right;">    mape</th><th>node_ip      </th><th style="text-align: right;">   pid</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  training_iteration</th><th>trial_id   </th></tr>
# </thead>
# <tbody>
# <tr><td>Trainable_10c93_00000</td><td>2023-07-01_11-07-57</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.796665</td><td style="text-align: right;"> 1.09199</td><td>172.26.215.93</td><td style="text-align: right;">205480</td><td style="text-align: right;">0.998567</td><td style="text-align: right;">            1.35742 </td><td style="text-align: right;">          1.35742 </td><td style="text-align: right;">      1.35742 </td><td style="text-align: right;"> 1688177277</td><td style="text-align: right;">                   1</td><td>10c93_00000</td></tr>
# <tr><td>Trainable_10c93_00001</td><td>2023-07-01_11-08-09</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.804721</td><td style="text-align: right;"> 1.05399</td><td>172.26.215.93</td><td style="text-align: right;">205481</td><td style="text-align: right;">1.00542 </td><td style="text-align: right;">           13.4919  </td><td style="text-align: right;">         13.4919  </td><td style="text-align: right;">     13.4919  </td><td style="text-align: right;"> 1688177289</td><td style="text-align: right;">                   1</td><td>10c93_00001</td></tr>
# <tr><td>Trainable_10c93_00002</td><td>2023-07-01_11-07-57</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.787497</td><td style="text-align: right;"> 1.04705</td><td>172.26.215.93</td><td style="text-align: right;">205482</td><td style="text-align: right;">0.986632</td><td style="text-align: right;">            2.38128 </td><td style="text-align: right;">          2.38128 </td><td style="text-align: right;">      2.38128 </td><td style="text-align: right;"> 1688177277</td><td style="text-align: right;">                   1</td><td>10c93_00002</td></tr>
# <tr><td>Trainable_10c93_00003</td><td>2023-07-01_11-07-56</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.803448</td><td style="text-align: right;"> 1.17208</td><td>172.26.215.93</td><td style="text-align: right;">205483</td><td style="text-align: right;">1.00751 </td><td style="text-align: right;">            1.14628 </td><td style="text-align: right;">          1.14628 </td><td style="text-align: right;">      1.14628 </td><td style="text-align: right;"> 1688177276</td><td style="text-align: right;">                   1</td><td>10c93_00003</td></tr>
# <tr><td>Trainable_10c93_00004</td><td>2023-07-01_11-07-59</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.796168</td><td style="text-align: right;"> 1.23012</td><td>172.26.215.93</td><td style="text-align: right;">205484</td><td style="text-align: right;">0.996956</td><td style="text-align: right;">            4.1471  </td><td style="text-align: right;">          4.1471  </td><td style="text-align: right;">      4.1471  </td><td style="text-align: right;"> 1688177279</td><td style="text-align: right;">                   1</td><td>10c93_00004</td></tr>
# <tr><td>Trainable_10c93_00005</td><td>2023-07-01_11-07-59</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.790286</td><td style="text-align: right;"> 1.02075</td><td>172.26.215.93</td><td style="text-align: right;">205485</td><td style="text-align: right;">0.995224</td><td style="text-align: right;">            4.05969 </td><td style="text-align: right;">          4.05969 </td><td style="text-align: right;">      4.05969 </td><td style="text-align: right;"> 1688177279</td><td style="text-align: right;">                   1</td><td>10c93_00005</td></tr>
# <tr><td>Trainable_10c93_00006</td><td>2023-07-01_11-08-05</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.80289 </td><td style="text-align: right;"> 1.57191</td><td>172.26.215.93</td><td style="text-align: right;">205486</td><td style="text-align: right;">1.00859 </td><td style="text-align: right;">            9.55607 </td><td style="text-align: right;">          9.55607 </td><td style="text-align: right;">      9.55607 </td><td style="text-align: right;"> 1688177285</td><td style="text-align: right;">                   1</td><td>10c93_00006</td></tr>
# <tr><td>Trainable_10c93_00007</td><td>2023-07-01_11-07-56</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.816287</td><td style="text-align: right;"> 2.72519</td><td>172.26.215.93</td><td style="text-align: right;">205487</td><td style="text-align: right;">1.02686 </td><td style="text-align: right;">            0.681098</td><td style="text-align: right;">          0.681098</td><td style="text-align: right;">      0.681098</td><td style="text-align: right;"> 1688177276</td><td style="text-align: right;">                   1</td><td>10c93_00007</td></tr>
# <tr><td>Trainable_10c93_00008</td><td>2023-07-01_11-08-13</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.793757</td><td style="text-align: right;"> 1.16331</td><td>172.26.215.93</td><td style="text-align: right;">206007</td><td style="text-align: right;">0.998171</td><td style="text-align: right;">            1.05929 </td><td style="text-align: right;">          1.05929 </td><td style="text-align: right;">      1.05929 </td><td style="text-align: right;"> 1688177293</td><td style="text-align: right;">                   1</td><td>10c93_00008</td></tr>
# <tr><td>Trainable_10c93_00009</td><td>2023-07-01_11-09-29</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.798588</td><td style="text-align: right;"> 1.12071</td><td>172.26.215.93</td><td style="text-align: right;">206010</td><td style="text-align: right;">0.997699</td><td style="text-align: right;">           75.8652  </td><td style="text-align: right;">         75.8652  </td><td style="text-align: right;">     75.8652  </td><td style="text-align: right;"> 1688177369</td><td style="text-align: right;">                   1</td><td>10c93_00009</td></tr>
# <tr><td>Trainable_10c93_00010</td><td>2023-07-01_11-08-14</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.793437</td><td style="text-align: right;"> 1.56006</td><td>172.26.215.93</td><td style="text-align: right;">206012</td><td style="text-align: right;">0.996252</td><td style="text-align: right;">            0.673734</td><td style="text-align: right;">          0.673734</td><td style="text-align: right;">      0.673734</td><td style="text-align: right;"> 1688177294</td><td style="text-align: right;">                   1</td><td>10c93_00010</td></tr>
# <tr><td>Trainable_10c93_00011</td><td>2023-07-01_11-08-14</td><td>True  </td><td>DESKTOP-0P789CI</td><td style="text-align: right;">
# 2023-07-01 11:22:21,297	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.538 s, which may be a performance bottleneck.
# 2023-07-01 11:22:21,304	WARNING util.py:315 -- The `process_trial_result` operation took 0.554 s, which may be a performance bottleneck.
# 2023-07-01 11:22:21,307	WARNING util.py:315 -- Processing trial results took 0.558 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:22:21,309	WARNING util.py:315 -- The `process_trial_result` operation took 0.560 s, which may be a performance bottleneck.
# 2023-07-01 11:23:30,112	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.567 s, which may be a performance bottleneck.
# 2023-07-01 11:23:30,117	WARNING util.py:315 -- The `process_trial_result` operation took 0.572 s, which may be a performance bottleneck.
# 2023-07-01 11:23:30,125	WARNING util.py:315 -- Processing trial results took 0.578 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:23:30,130	WARNING util.py:315 -- The `process_trial_result` operation took 0.586 s, which may be a performance bottleneck.
# 2023-07-01 11:24:29,287	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.600 s, which may be a performance bottleneck.
# 2023-07-01 11:24:29,295	WARNING util.py:315 -- The `process_trial_result` operation took 0.608 s, which may be a performance bottleneck.
# 2023-07-01 11:24:29,307	WARNING util.py:315 -- Processing trial results took 0.620 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:24:29,312	WARNING util.py:315 -- The `process_trial_result` operation took 0.625 s, which may be a performance bottleneck.
# 2023-07-01 11:25:29,650	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.545 s, which may be a performance bottleneck.
# 2023-07-01 11:25:29,654	WARNING util.py:315 -- The `process_trial_result` operation took 0.550 s, which may be a performance bottleneck.
# 2023-07-01 11:25:29,663	WARNING util.py:315 -- Processing trial results took 0.559 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:25:29,668	WARNING util.py:315 -- The `process_trial_result` operation took 0.564 s, which may be a performance bottleneck.
# 2023-07-01 11:25:30,219	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.537 s, which may be a performance bottleneck.
# 2023-07-01 11:25:30,228	WARNING util.py:315 -- The `process_trial_result` operation took 0.546 s, which may be a performance bottleneck.
# 2023-07-01 11:25:30,233	WARNING util.py:315 -- Processing trial results took 0.552 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:25:30,264	WARNING util.py:315 -- The `process_trial_result` operation took 0.583 s, which may be a performance bottleneck.
# 2023-07-01 11:26:27,614	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2023-07-01 11:26:27,626	WARNING util.py:315 -- The `process_trial_result` operation took 0.545 s, which may be a performance bottleneck.
# 2023-07-01 11:26:27,629	WARNING util.py:315 -- Processing trial results took 0.548 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:26:27,636	WARNING util.py:315 -- The `process_trial_result` operation took 0.555 s, which may be a performance bottleneck.
# 2023-07-01 11:26:28,857	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.567 s, which may be a performance bottleneck.
# 2023-07-01 11:26:28,868	WARNING util.py:315 -- The `process_trial_result` operation took 0.577 s, which may be a performance bottleneck.
# 2023-07-01 11:26:28,883	WARNING util.py:315 -- Processing trial results took 0.593 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:26:28,886	WARNING util.py:315 -- The `process_trial_result` operation took 0.596 s, which may be a performance bottleneck.
# 2023-07-01 11:28:11,403	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.672 s, which may be a performance bottleneck.
# 2023-07-01 11:28:11,426	WARNING util.py:315 -- The `process_trial_result` operation took 0.695 s, which may be a performance bottleneck.
# 2023-07-01 11:28:11,429	WARNING util.py:315 -- Processing trial results took 0.697 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:28:11,431	WARNING util.py:315 -- The `process_trial_result` operation took 0.699 s, which may be a performance bottleneck.
# 2023-07-01 11:29:09,342	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2023-07-01 11:29:09,346	WARNING util.py:315 -- The `process_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2023-07-01 11:29:09,352	WARNING util.py:315 -- Processing trial results took 0.513 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:29:09,356	WARNING util.py:315 -- The `process_trial_result` operation took 0.516 s, which may be a performance bottleneck.
# 2023-07-01 11:29:29,194	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.591 s, which may be a performance bottleneck.
# 2023-07-01 11:29:29,206	WARNING util.py:315 -- The `process_trial_result` operation took 0.604 s, which may be a performance bottleneck.
# 2023-07-01 11:29:29,208	WARNING util.py:315 -- Processing trial results took 0.606 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:29:29,210	WARNING util.py:315 -- The `process_trial_result` operation took 0.607 s, which may be a performance bottleneck.
# 2023-07-01 11:29:48,814	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.646 s, which may be a performance bottleneck.
# 2023-07-01 11:29:48,818	WARNING util.py:315 -- The `process_trial_result` operation took 0.649 s, which may be a performance bottleneck.
# 2023-07-01 11:29:48,830	WARNING util.py:315 -- Processing trial results took 0.662 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:29:48,832	WARNING util.py:315 -- The `process_trial_result` operation took 0.664 s, which may be a performance bottleneck.
# 2023-07-01 11:29:52,579	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.621 s, which may be a performance bottleneck.
# 2023-07-01 11:29:52,614	WARNING util.py:315 -- The `process_trial_result` operation took 0.656 s, which may be a performance bottleneck.
# 2023-07-01 11:29:52,617	WARNING util.py:315 -- Processing trial results took 0.658 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:29:52,626	WARNING util.py:315 -- The `process_trial_result` operation took 0.668 s, which may be a performance bottleneck.
# 2023-07-01 11:30:14,476	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.537 s, which may be a performance bottleneck.
# 2023-07-01 11:30:14,486	WARNING util.py:315 -- The `process_trial_result` operation took 0.547 s, which may be a performance bottleneck.
# 2023-07-01 11:30:14,499	WARNING util.py:315 -- Processing trial results took 0.561 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:30:14,501	WARNING util.py:315 -- The `process_trial_result` operation took 0.562 s, which may be a performance bottleneck.
# 2023-07-01 11:30:50,442	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.590 s, which may be a performance bottleneck.
# 2023-07-01 11:30:50,452	WARNING util.py:315 -- The `process_trial_result` operation took 0.600 s, which may be a performance bottleneck.
# 2023-07-01 11:30:50,454	WARNING util.py:315 -- Processing trial results took 0.603 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:30:50,459	WARNING util.py:315 -- The `process_trial_result` operation took 0.608 s, which may be a performance bottleneck.
# 2023-07-01 11:30:59,579	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.553 s, which may be a performance bottleneck.
# 2023-07-01 11:30:59,583	WARNING util.py:315 -- The `process_trial_result` operation took 0.558 s, which may be a performance bottleneck.
# 2023-07-01 11:30:59,594	WARNING util.py:315 -- Processing trial results took 0.569 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:30:59,598	WARNING util.py:315 -- The `process_trial_result` operation took 0.572 s, which may be a performance bottleneck.
# 2023-07-01 11:31:41,324	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2023-07-01 11:31:41,328	WARNING util.py:315 -- The `process_trial_result` operation took 0.519 s, which may be a performance bottleneck.
# 2023-07-01 11:31:41,335	WARNING util.py:315 -- Processing trial results took 0.525 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:31:41,337	WARNING util.py:315 -- The `process_trial_result` operation took 0.527 s, which may be a performance bottleneck.
# 2023-07-01 11:32:39,976	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2023-07-01 11:32:39,981	WARNING util.py:315 -- The `process_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2023-07-01 11:32:39,989	WARNING util.py:315 -- Processing trial results took 0.536 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:32:39,993	WARNING util.py:315 -- The `process_trial_result` operation took 0.541 s, which may be a performance bottleneck.
# 2023-07-01 11:33:00,856	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.556 s, which may be a performance bottleneck.
# 2023-07-01 11:33:00,864	WARNING util.py:315 -- The `process_trial_result` operation took 0.565 s, which may be a performance bottleneck.
# 2023-07-01 11:33:00,870	WARNING util.py:315 -- Processing trial results took 0.571 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:33:00,872	WARNING util.py:315 -- The `process_trial_result` operation took 0.573 s, which may be a performance bottleneck.
# 2023-07-01 11:33:13,834	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.547 s, which may be a performance bottleneck.
# 2023-07-01 11:33:13,838	WARNING util.py:315 -- The `process_trial_result` operation took 0.550 s, which may be a performance bottleneck.
# 2023-07-01 11:33:13,840	WARNING util.py:315 -- Processing trial results took 0.553 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:33:13,843	WARNING util.py:315 -- The `process_trial_result` operation took 0.556 s, which may be a performance bottleneck.
# 2023-07-01 11:33:17,594	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.501 s, which may be a performance bottleneck.
# 2023-07-01 11:33:17,602	WARNING util.py:315 -- The `process_trial_result` operation took 0.509 s, which may be a performance bottleneck.
# 2023-07-01 11:33:17,605	WARNING util.py:315 -- Processing trial results took 0.513 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:33:17,608	WARNING util.py:315 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2023-07-01 11:33:42,196	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.844 s, which may be a performance bottleneck.
# 2023-07-01 11:33:42,213	WARNING util.py:315 -- The `process_trial_result` operation took 0.862 s, which may be a performance bottleneck.
# 2023-07-01 11:33:42,215	WARNING util.py:315 -- Processing trial results took 0.863 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:33:42,217	WARNING util.py:315 -- The `process_trial_result` operation took 0.866 s, which may be a performance bottleneck.
# 2023-07-01 11:34:27,556	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.531 s, which may be a performance bottleneck.
# 2023-07-01 11:34:27,568	WARNING util.py:315 -- The `process_trial_result` operation took 0.544 s, which may be a performance bottleneck.
# 2023-07-01 11:34:27,575	WARNING util.py:315 -- Processing trial results took 0.551 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:34:27,578	WARNING util.py:315 -- The `process_trial_result` operation took 0.554 s, which may be a performance bottleneck.
# 2023-07-01 11:34:59,762	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.630 s, which may be a performance bottleneck.
# 2023-07-01 11:34:59,768	WARNING util.py:315 -- The `process_trial_result` operation took 0.637 s, which may be a performance bottleneck.
# 2023-07-01 11:34:59,771	WARNING util.py:315 -- Processing trial results took 0.640 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:34:59,773	WARNING util.py:315 -- The `process_trial_result` operation took 0.642 s, which may be a performance bottleneck.
# 2023-07-01 11:35:11,825	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.605 s, which may be a performance bottleneck.
# 2023-07-01 11:35:11,831	WARNING util.py:315 -- The `process_trial_result` operation took 0.612 s, which may be a performance bottleneck.
# 2023-07-01 11:35:11,834	WARNING util.py:315 -- Processing trial results took 0.615 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:35:11,838	WARNING util.py:315 -- The `process_trial_result` operation took 0.619 s, which may be a performance bottleneck.
# 2023-07-01 11:35:13,469	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.806 s, which may be a performance bottleneck.
# 2023-07-01 11:35:13,474	WARNING util.py:315 -- The `process_trial_result` operation took 0.810 s, which may be a performance bottleneck.
# 2023-07-01 11:35:13,492	WARNING util.py:315 -- Processing trial results took 0.812 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:35:13,499	WARNING util.py:315 -- The `process_trial_result` operation took 0.835 s, which may be a performance bottleneck.
# 2023-07-01 11:35:23,132	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.545 s, which may be a performance bottleneck.
# 2023-07-01 11:35:23,144	WARNING util.py:315 -- The `process_trial_result` operation took 0.556 s, which may be a performance bottleneck.
# 2023-07-01 11:35:23,148	WARNING util.py:315 -- Processing trial results took 0.561 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:35:23,150	WARNING util.py:315 -- The `process_trial_result` operation took 0.563 s, which may be a performance bottleneck.
# 2023-07-01 11:35:45,772	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.590 s, which may be a performance bottleneck.
# 2023-07-01 11:35:45,778	WARNING util.py:315 -- The `process_trial_result` operation took 0.596 s, which may be a performance bottleneck.
# 2023-07-01 11:35:45,783	WARNING util.py:315 -- Processing trial results took 0.601 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:35:45,790	WARNING util.py:315 -- The `process_trial_result` operation took 0.608 s, which may be a performance bottleneck.
# 2023-07-01 11:35:46,596	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.734 s, which may be a performance bottleneck.
# 2023-07-01 11:35:46,609	WARNING util.py:315 -- The `process_trial_result` operation took 0.748 s, which may be a performance bottleneck.
# 2023-07-01 11:35:46,612	WARNING util.py:315 -- Processing trial results took 0.751 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:35:46,614	WARNING util.py:315 -- The `process_trial_result` operation took 0.753 s, which may be a performance bottleneck.
# 2023-07-01 11:35:49,266	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.845 s, which may be a performance bottleneck.
# 2023-07-01 11:35:49,290	WARNING util.py:315 -- The `process_trial_result` operation took 0.870 s, which may be a performance bottleneck.
# 2023-07-01 11:35:49,293	WARNING util.py:315 -- Processing trial results took 0.872 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:35:49,295	WARNING util.py:315 -- The `process_trial_result` operation took 0.875 s, which may be a performance bottleneck.
# 2023-07-01 11:36:08,516	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.576 s, which may be a performance bottleneck.
# 2023-07-01 11:36:08,548	WARNING util.py:315 -- The `process_trial_result` operation took 0.607 s, which may be a performance bottleneck.
# 2023-07-01 11:36:08,563	WARNING util.py:315 -- Processing trial results took 0.623 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:36:08,579	WARNING util.py:315 -- The `process_trial_result` operation took 0.639 s, which may be a performance bottleneck.
# 2023-07-01 11:36:09,782	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.564 s, which may be a performance bottleneck.
# 2023-07-01 11:36:09,791	WARNING util.py:315 -- The `process_trial_result` operation took 0.576 s, which may be a performance bottleneck.
# 2023-07-01 11:36:09,794	WARNING util.py:315 -- Processing trial results took 0.579 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:36:09,799	WARNING util.py:315 -- The `process_trial_result` operation took 0.585 s, which may be a performance bottleneck.
# 2023-07-01 11:36:11,804	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.798 s, which may be a performance bottleneck.
# 2023-07-01 11:36:11,809	WARNING util.py:315 -- The `process_trial_result` operation took 0.804 s, which may be a performance bottleneck.
# 2023-07-01 11:36:11,815	WARNING util.py:315 -- Processing trial results took 0.810 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:36:11,818	WARNING util.py:315 -- The `process_trial_result` operation took 0.813 s, which may be a performance bottleneck.
# 2023-07-01 11:36:22,137	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2023-07-01 11:36:22,144	WARNING util.py:315 -- The `process_trial_result` operation took 0.535 s, which may be a performance bottleneck.
# 2023-07-01 11:36:22,148	WARNING util.py:315 -- Processing trial results took 0.539 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:36:22,151	WARNING util.py:315 -- The `process_trial_result` operation took 0.542 s, which may be a performance bottleneck.
# 2023-07-01 11:36:29,940	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.524 s, which may be a performance bottleneck.
# 2023-07-01 11:36:29,945	WARNING util.py:315 -- The `process_trial_result` operation took 0.530 s, which may be a performance bottleneck.
# 2023-07-01 11:36:29,957	WARNING util.py:315 -- Processing trial results took 0.542 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:36:29,960	WARNING util.py:315 -- The `process_trial_result` operation took 0.545 s, which may be a performance bottleneck.
# 2023-07-01 11:36:30,967	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.524 s, which may be a performance bottleneck.
# 2023-07-01 11:36:30,971	WARNING util.py:315 -- The `process_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2023-07-01 11:36:31,002	WARNING util.py:315 -- Processing trial results took 0.559 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:36:31,004	WARNING util.py:315 -- The `process_trial_result` operation took 0.562 s, which may be a performance bottleneck.
# 2023-07-01 11:36:31,557	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.544 s, which may be a performance bottleneck.
# 2023-07-01 11:36:31,571	WARNING util.py:315 -- The `process_trial_result` operation took 0.552 s, which may be a performance bottleneck.
# 2023-07-01 11:36:31,575	WARNING util.py:315 -- Processing trial results took 0.562 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:36:31,578	WARNING util.py:315 -- The `process_trial_result` operation took 0.565 s, which may be a performance bottleneck.
# 2023-07-01 11:36:35,552	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.714 s, which may be a performance bottleneck.
# 2023-07-01 11:36:35,585	WARNING util.py:315 -- The `process_trial_result` operation took 0.747 s, which may be a performance bottleneck.
# 2023-07-01 11:36:35,586	WARNING util.py:315 -- Processing trial results took 0.749 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:36:35,605	WARNING util.py:315 -- The `process_trial_result` operation took 0.767 s, which may be a performance bottleneck.
# 2023-07-01 11:36:53,868	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.537 s, which may be a performance bottleneck.
# 2023-07-01 11:36:53,871	WARNING util.py:315 -- The `process_trial_result` operation took 0.540 s, which may be a performance bottleneck.
# 2023-07-01 11:36:53,885	WARNING util.py:315 -- Processing trial results took 0.555 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:36:53,888	WARNING util.py:315 -- The `process_trial_result` operation took 0.558 s, which may be a performance bottleneck.
# 2023-07-01 11:36:56,311	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.589 s, which may be a performance bottleneck.
# 2023-07-01 11:36:56,315	WARNING util.py:315 -- The `process_trial_result` operation took 0.593 s, which may be a performance bottleneck.
# 2023-07-01 11:36:56,325	WARNING util.py:315 -- Processing trial results took 0.604 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:36:56,327	WARNING util.py:315 -- The `process_trial_result` operation took 0.605 s, which may be a performance bottleneck.
# 2023-07-01 11:37:07,965	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2023-07-01 11:37:07,972	WARNING util.py:315 -- The `process_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2023-07-01 11:37:07,980	WARNING util.py:315 -- Processing trial results took 0.523 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:37:07,983	WARNING util.py:315 -- The `process_trial_result` operation took 0.525 s, which may be a performance bottleneck.
# 2023-07-01 11:37:15,382	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.524 s, which may be a performance bottleneck.
# 2023-07-01 11:37:15,387	WARNING util.py:315 -- The `process_trial_result` operation took 0.529 s, which may be a performance bottleneck.
# 2023-07-01 11:37:15,389	WARNING util.py:315 -- Processing trial results took 0.531 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:37:15,393	WARNING util.py:315 -- The `process_trial_result` operation took 0.535 s, which may be a performance bottleneck.
# 2023-07-01 11:37:16,375	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.555 s, which may be a performance bottleneck.
# 2023-07-01 11:37:16,380	WARNING util.py:315 -- The `process_trial_result` operation took 0.561 s, which may be a performance bottleneck.
# 2023-07-01 11:37:16,383	WARNING util.py:315 -- Processing trial results took 0.564 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:37:16,384	WARNING util.py:315 -- The `process_trial_result` operation took 0.565 s, which may be a performance bottleneck.
# 2023-07-01 11:37:30,775	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.550 s, which may be a performance bottleneck.
# 2023-07-01 11:37:30,784	WARNING util.py:315 -- The `process_trial_result` operation took 0.559 s, which may be a performance bottleneck.
# 2023-07-01 11:37:30,787	WARNING util.py:315 -- Processing trial results took 0.562 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:37:30,789	WARNING util.py:315 -- The `process_trial_result` operation took 0.564 s, which may be a performance bottleneck.
# 2023-07-01 11:37:31,436	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2023-07-01 11:37:31,441	WARNING util.py:315 -- The `process_trial_result` operation took 0.522 s, which may be a performance bottleneck.
# 2023-07-01 11:37:31,444	WARNING util.py:315 -- Processing trial results took 0.525 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:37:31,447	WARNING util.py:315 -- The `process_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2023-07-01 11:37:34,074	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.630 s, which may be a performance bottleneck.
# 2023-07-01 11:37:34,077	WARNING util.py:315 -- The `process_trial_result` operation took 0.634 s, which may be a performance bottleneck.
# 2023-07-01 11:37:34,081	WARNING util.py:315 -- Processing trial results took 0.638 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:37:34,083	WARNING util.py:315 -- The `process_trial_result` operation took 0.640 s, which may be a performance bottleneck.
# 2023-07-01 11:37:37,242	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.606 s, which may be a performance bottleneck.
# 2023-07-01 11:37:37,247	WARNING util.py:315 -- The `process_trial_result` operation took 0.612 s, which may be a performance bottleneck.
# 2023-07-01 11:37:37,249	WARNING util.py:315 -- Processing trial results took 0.614 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:37:37,252	WARNING util.py:315 -- The `process_trial_result` operation took 0.617 s, which may be a performance bottleneck.
# 2023-07-01 11:37:50,972	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.816 s, which may be a performance bottleneck.
# 2023-07-01 11:37:50,975	WARNING util.py:315 -- The `process_trial_result` operation took 0.822 s, which may be a performance bottleneck.
# 2023-07-01 11:37:50,977	WARNING util.py:315 -- Processing trial results took 0.824 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:37:50,979	WARNING util.py:315 -- The `process_trial_result` operation took 0.826 s, which may be a performance bottleneck.
# 2023-07-01 11:38:03,213	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.677 s, which may be a performance bottleneck.
# 2023-07-01 11:38:03,223	WARNING util.py:315 -- The `process_trial_result` operation took 0.688 s, which may be a performance bottleneck.
# 2023-07-01 11:38:03,226	WARNING util.py:315 -- Processing trial results took 0.691 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:38:03,228	WARNING util.py:315 -- The `process_trial_result` operation took 0.693 s, which may be a performance bottleneck.
# 2023-07-01 11:38:03,922	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.688 s, which may be a performance bottleneck.
# 2023-07-01 11:38:03,928	WARNING util.py:315 -- The `process_trial_result` operation took 0.695 s, which may be a performance bottleneck.
# 2023-07-01 11:38:03,941	WARNING util.py:315 -- Processing trial results took 0.708 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:38:03,952	WARNING util.py:315 -- The `process_trial_result` operation took 0.718 s, which may be a performance bottleneck.
# 2023-07-01 11:38:23,535	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.738 s, which may be a performance bottleneck.
# 2023-07-01 11:38:23,551	WARNING util.py:315 -- The `process_trial_result` operation took 0.754 s, which may be a performance bottleneck.
# 2023-07-01 11:38:23,566	WARNING util.py:315 -- Processing trial results took 0.769 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:38:23,568	WARNING util.py:315 -- The `process_trial_result` operation took 0.771 s, which may be a performance bottleneck.
# 2023-07-01 11:38:50,038	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.552 s, which may be a performance bottleneck.
# 2023-07-01 11:38:50,043	WARNING util.py:315 -- The `process_trial_result` operation took 0.557 s, which may be a performance bottleneck.
# 2023-07-01 11:38:50,049	WARNING util.py:315 -- Processing trial results took 0.563 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:38:50,051	WARNING util.py:315 -- The `process_trial_result` operation took 0.566 s, which may be a performance bottleneck.
# 2023-07-01 11:38:58,314	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.551 s, which may be a performance bottleneck.
# 2023-07-01 11:38:58,317	WARNING util.py:315 -- The `process_trial_result` operation took 0.555 s, which may be a performance bottleneck.
# 2023-07-01 11:38:58,324	WARNING util.py:315 -- Processing trial results took 0.562 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:38:58,326	WARNING util.py:315 -- The `process_trial_result` operation took 0.564 s, which may be a performance bottleneck.
# 2023-07-01 11:39:04,196	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.522 s, which may be a performance bottleneck.
# 2023-07-01 11:39:04,204	WARNING util.py:315 -- The `process_trial_result` operation took 0.530 s, which may be a performance bottleneck.
# ...
# 2023-07-01 11:53:57,350	WARNING util.py:315 -- The `process_trial_result` operation took 0.713 s, which may be a performance bottleneck.
# 2023-07-01 11:54:01,324	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.988 s, which may be a performance bottleneck.
# 2023-07-01 11:54:01,338	WARNING util.py:315 -- The `process_trial_result` operation took 1.002 s, which may be a performance bottleneck.
# 2023-07-01 11:54:01,356	WARNING util.py:315 -- Processing trial results took 1.020 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:01,359	WARNING util.py:315 -- The `process_trial_result` operation took 1.024 s, which may be a performance bottleneck.
# 2023-07-01 11:54:03,135	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.833 s, which may be a performance bottleneck.
# 2023-07-01 11:54:03,148	WARNING util.py:315 -- The `process_trial_result` operation took 0.846 s, which may be a performance bottleneck.
# 2023-07-01 11:54:03,152	WARNING util.py:315 -- Processing trial results took 0.850 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:03,157	WARNING util.py:315 -- The `process_trial_result` operation took 0.856 s, which may be a performance bottleneck.
# 2023-07-01 11:54:04,354	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 1.021 s, which may be a performance bottleneck.
# 2023-07-01 11:54:04,364	WARNING util.py:315 -- The `process_trial_result` operation took 1.032 s, which may be a performance bottleneck.
# 2023-07-01 11:54:04,366	WARNING util.py:315 -- Processing trial results took 1.034 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:04,372	WARNING util.py:315 -- The `process_trial_result` operation took 1.040 s, which may be a performance bottleneck.
# 2023-07-01 11:54:06,268	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.989 s, which may be a performance bottleneck.
# 2023-07-01 11:54:06,309	WARNING util.py:315 -- The `process_trial_result` operation took 1.035 s, which may be a performance bottleneck.
# 2023-07-01 11:54:06,322	WARNING util.py:315 -- Processing trial results took 1.048 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:06,326	WARNING util.py:315 -- The `process_trial_result` operation took 1.051 s, which may be a performance bottleneck.
# 2023-07-01 11:54:22,889	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.739 s, which may be a performance bottleneck.
# 2023-07-01 11:54:22,893	WARNING util.py:315 -- The `process_trial_result` operation took 0.743 s, which may be a performance bottleneck.
# 2023-07-01 11:54:22,903	WARNING util.py:315 -- Processing trial results took 0.752 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:22,904	WARNING util.py:315 -- The `process_trial_result` operation took 0.754 s, which may be a performance bottleneck.
# 2023-07-01 11:54:24,140	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.949 s, which may be a performance bottleneck.
# 2023-07-01 11:54:24,146	WARNING util.py:315 -- The `process_trial_result` operation took 0.954 s, which may be a performance bottleneck.
# 2023-07-01 11:54:24,150	WARNING util.py:315 -- Processing trial results took 0.958 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:24,152	WARNING util.py:315 -- The `process_trial_result` operation took 0.961 s, which may be a performance bottleneck.
# 2023-07-01 11:54:27,856	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 1.096 s, which may be a performance bottleneck.
# 2023-07-01 11:54:27,864	WARNING util.py:315 -- The `process_trial_result` operation took 1.104 s, which may be a performance bottleneck.
# 2023-07-01 11:54:27,870	WARNING util.py:315 -- Processing trial results took 1.110 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:27,872	WARNING util.py:315 -- The `process_trial_result` operation took 1.112 s, which may be a performance bottleneck.
# 2023-07-01 11:54:29,640	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.915 s, which may be a performance bottleneck.
# 2023-07-01 11:54:29,656	WARNING util.py:315 -- The `process_trial_result` operation took 0.931 s, which may be a performance bottleneck.
# 2023-07-01 11:54:29,660	WARNING util.py:315 -- Processing trial results took 0.935 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:29,662	WARNING util.py:315 -- The `process_trial_result` operation took 0.937 s, which may be a performance bottleneck.
# 2023-07-01 11:54:34,886	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 1.050 s, which may be a performance bottleneck.
# 2023-07-01 11:54:34,890	WARNING util.py:315 -- The `process_trial_result` operation took 1.054 s, which may be a performance bottleneck.
# 2023-07-01 11:54:34,914	WARNING util.py:315 -- Processing trial results took 1.077 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:34,918	WARNING util.py:315 -- The `process_trial_result` operation took 1.082 s, which may be a performance bottleneck.
# 2023-07-01 11:54:53,310	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.694 s, which may be a performance bottleneck.
# 2023-07-01 11:54:53,316	WARNING util.py:315 -- The `process_trial_result` operation took 0.701 s, which may be a performance bottleneck.
# 2023-07-01 11:54:53,331	WARNING util.py:315 -- Processing trial results took 0.715 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:53,334	WARNING util.py:315 -- The `process_trial_result` operation took 0.718 s, which may be a performance bottleneck.
# 2023-07-01 11:54:54,423	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.752 s, which may be a performance bottleneck.
# 2023-07-01 11:54:54,437	WARNING util.py:315 -- The `process_trial_result` operation took 0.766 s, which may be a performance bottleneck.
# 2023-07-01 11:54:54,445	WARNING util.py:315 -- Processing trial results took 0.774 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:54,449	WARNING util.py:315 -- The `process_trial_result` operation took 0.778 s, which may be a performance bottleneck.
# 2023-07-01 11:54:59,324	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 1.099 s, which may be a performance bottleneck.
# 2023-07-01 11:54:59,330	WARNING util.py:315 -- The `process_trial_result` operation took 1.105 s, which may be a performance bottleneck.
# 2023-07-01 11:54:59,346	WARNING util.py:315 -- Processing trial results took 1.121 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:54:59,358	WARNING util.py:315 -- The `process_trial_result` operation took 1.133 s, which may be a performance bottleneck.
# 2023-07-01 11:55:00,901	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.980 s, which may be a performance bottleneck.
# 2023-07-01 11:55:00,907	WARNING util.py:315 -- The `process_trial_result` operation took 0.987 s, which may be a performance bottleneck.
# 2023-07-01 11:55:00,910	WARNING util.py:315 -- Processing trial results took 0.989 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:55:00,914	WARNING util.py:315 -- The `process_trial_result` operation took 0.994 s, which may be a performance bottleneck.
# 2023-07-01 11:55:09,232	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.728 s, which may be a performance bottleneck.
# 2023-07-01 11:55:09,234	WARNING util.py:315 -- The `process_trial_result` operation took 0.731 s, which may be a performance bottleneck.
# 2023-07-01 11:55:09,237	WARNING util.py:315 -- Processing trial results took 0.734 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:55:09,245	WARNING util.py:315 -- The `process_trial_result` operation took 0.736 s, which may be a performance bottleneck.
# 2023-07-01 11:55:17,448	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.712 s, which may be a performance bottleneck.
# 2023-07-01 11:55:17,456	WARNING util.py:315 -- The `process_trial_result` operation took 0.721 s, which may be a performance bottleneck.
# 2023-07-01 11:55:17,459	WARNING util.py:315 -- Processing trial results took 0.723 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:55:17,461	WARNING util.py:315 -- The `process_trial_result` operation took 0.725 s, which may be a performance bottleneck.
# 2023-07-01 11:55:22,356	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.690 s, which may be a performance bottleneck.
# 2023-07-01 11:55:22,363	WARNING util.py:315 -- The `process_trial_result` operation took 0.698 s, which may be a performance bottleneck.
# 2023-07-01 11:55:22,365	WARNING util.py:315 -- Processing trial results took 0.700 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:55:22,368	WARNING util.py:315 -- The `process_trial_result` operation took 0.703 s, which may be a performance bottleneck.
# 2023-07-01 11:55:23,446	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.947 s, which may be a performance bottleneck.
# 2023-07-01 11:55:23,459	WARNING util.py:315 -- The `process_trial_result` operation took 0.960 s, which may be a performance bottleneck.
# 2023-07-01 11:55:23,461	WARNING util.py:315 -- Processing trial results took 0.962 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:55:23,464	WARNING util.py:315 -- The `process_trial_result` operation took 0.965 s, which may be a performance bottleneck.
# 2023-07-01 11:55:30,587	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.848 s, which may be a performance bottleneck.
# 2023-07-01 11:55:30,592	WARNING util.py:315 -- The `process_trial_result` operation took 0.853 s, which may be a performance bottleneck.
# 2023-07-01 11:55:30,595	WARNING util.py:315 -- Processing trial results took 0.856 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:55:30,600	WARNING util.py:315 -- The `process_trial_result` operation took 0.861 s, which may be a performance bottleneck.
# 2023-07-01 11:55:42,385	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.935 s, which may be a performance bottleneck.
# 2023-07-01 11:55:42,391	WARNING util.py:315 -- The `process_trial_result` operation took 0.942 s, which may be a performance bottleneck.
# 2023-07-01 11:55:42,394	WARNING util.py:315 -- Processing trial results took 0.944 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:55:42,396	WARNING util.py:315 -- The `process_trial_result` operation took 0.947 s, which may be a performance bottleneck.
# 2023-07-01 11:55:49,802	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.600 s, which may be a performance bottleneck.
# 2023-07-01 11:55:49,806	WARNING util.py:315 -- The `process_trial_result` operation took 0.604 s, which may be a performance bottleneck.
# 2023-07-01 11:55:49,817	WARNING util.py:315 -- Processing trial results took 0.615 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:55:49,819	WARNING util.py:315 -- The `process_trial_result` operation took 0.617 s, which may be a performance bottleneck.
# 2023-07-01 11:55:50,658	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.832 s, which may be a performance bottleneck.
# 2023-07-01 11:55:50,669	WARNING util.py:315 -- The `process_trial_result` operation took 0.844 s, which may be a performance bottleneck.
# 2023-07-01 11:55:50,679	WARNING util.py:315 -- Processing trial results took 0.853 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:55:50,684	WARNING util.py:315 -- The `process_trial_result` operation took 0.859 s, which may be a performance bottleneck.
# 2023-07-01 11:56:12,294	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.548 s, which may be a performance bottleneck.
# 2023-07-01 11:56:12,297	WARNING util.py:315 -- The `process_trial_result` operation took 0.552 s, which may be a performance bottleneck.
# 2023-07-01 11:56:12,299	WARNING util.py:315 -- Processing trial results took 0.554 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:56:12,301	WARNING util.py:315 -- The `process_trial_result` operation took 0.556 s, which may be a performance bottleneck.
# 2023-07-01 11:56:19,666	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.637 s, which may be a performance bottleneck.
# 2023-07-01 11:56:19,671	WARNING util.py:315 -- The `process_trial_result` operation took 0.642 s, which may be a performance bottleneck.
# 2023-07-01 11:56:19,681	WARNING util.py:315 -- Processing trial results took 0.653 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:56:19,683	WARNING util.py:315 -- The `process_trial_result` operation took 0.655 s, which may be a performance bottleneck.
# 2023-07-01 11:56:26,748	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.603 s, which may be a performance bottleneck.
# 2023-07-01 11:56:26,755	WARNING util.py:315 -- The `process_trial_result` operation took 0.611 s, which may be a performance bottleneck.
# 2023-07-01 11:56:26,761	WARNING util.py:315 -- Processing trial results took 0.617 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:56:26,766	WARNING util.py:315 -- The `process_trial_result` operation took 0.622 s, which may be a performance bottleneck.
# 2023-07-01 11:56:29,905	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.960 s, which may be a performance bottleneck.
# 2023-07-01 11:56:29,912	WARNING util.py:315 -- The `process_trial_result` operation took 0.967 s, which may be a performance bottleneck.
# 2023-07-01 11:56:29,925	WARNING util.py:315 -- Processing trial results took 0.980 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:56:29,927	WARNING util.py:315 -- The `process_trial_result` operation took 0.982 s, which may be a performance bottleneck.
# 2023-07-01 11:56:35,357	WARNING util.py:315 -- The `callbacks.on_trial_result` operation took 0.658 s, which may be a performance bottleneck.
# 2023-07-01 11:56:35,361	WARNING util.py:315 -- The `process_trial_result` operation took 0.662 s, which may be a performance bottleneck.
# 2023-07-01 11:56:35,363	WARNING util.py:315 -- Processing trial results took 0.664 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-07-01 11:56:35,366	WARNING util.py:315 -- The `process_trial_result` operation took 0.667 s, which may be a performance bottleneck.
